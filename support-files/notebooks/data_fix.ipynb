# %%
import pandas as pd
import numpy as np
import random
import re

# =========================
# LOAD DATA
# =========================

df = pd.read_csv("../data/amazon_products_sales_data_cleaned.csv")

# %%
# !pin install pandas
